# %% [markdown]
# **Simple** **Quiz** **Program**

# %%
Q1='''What is a correct syntax to output "Hello World" in Python?


p("Hello World")
echo("Hello World");
echo "Hello World"
print("Hello World")'''

Q2='''Which one is NOT a legal variable name?

my_var    
_myvar
Myvar
my-var '''

Q3='''What is the correct file extension for Python files?

.py     
.pyt
.pt
.pyth'''

Q4='''What is the correct syntax to output the type of a variable or object in Python?

print(typeof x)
print(type(x))      
print(typeof(x))
print(typeOf(x))'''

Q5='''Which method can be used to remove any whitespace from both the beginning and the end of a string?

strip()     
ptrim()
len()
trim()'''

Q5='''Which method can be used to return a string in upper case letters?

upper()      
uppercase()
upperCase()
toUpperCase()'''

Q6='''Which method can be used to replace parts of a string?

replace()      
replaceString()
repl()
switch()'''

Q7='''Which operator is used to multiply numbers?

#
x
%
* '''

Q8='''Which statement is used to stop a loop?

return
break      
exit
stop'''

Q9='''Which of these collections defines a DICTIONARY?

("apple", "banana", "cherry")
["apple", "banana", "cherry"]
{"apple", "banana", "cherry"}
{"name": "apple", "color": "green"}'''

Q10='''Which method can be used to remove any whitespace from both the beginning and the end of a string?

len()
trim()
strip()
ptrim()'''

questions={Q1:'d',Q2:'a',Q3:'a',Q4:'b',Q5:'a',Q6:'a',Q7:'d',Q8:'b',Q9:'d',Q10:'c'}
name=input("Enter your name: ")
print("Hello",name)
print("Your quiz starts now\n All the best")

score=0
for i in questions:
  print(i)
  answer=input("Enter your answer (a/b/c/d): ")
  if questions[i]==answer:
   print('Correct answer, You got 1 point')
   score=score+1
  else:
    print('wrong answer, You lost 1 point')
    score=score-1

print('Your final score is: ', score)
# Out:
# Enter your name: Tameem
# Hello Tameem
# Your quiz starts now
#  All the best
# What is a correct syntax to output "Hello World" in Python?
#
#
# p("Hello World")
# echo("Hello World");
# echo "Hello World"
# print("Hello World")
# Enter your answer (a/b/c/d): a
# wrong answer, You lost 1 point
# Which one is NOT a legal variable name?
#
# my_var
# _myvar
# Myvar
# my-var
# Enter your answer (a/b/c/d): a
# Correct answer, You got 1 point
# What is the correct file extension for Python files?
#
# .py
# .pyt
# .pt
# .pyth
# Enter your answer (a/b/c/d): a
# Enter your answer (a/b/c/d): a
# Correct answer, You got 1 point
# What is the correct syntax to output the type of a variable or object in Python?
#
# print(typeof x)
# print(type(x))
# print(typeof(x))
# print(typeOf(x))
# wrong answer, You lost 1 point
# Which method can be used to return a string in upper case letters?
#
# upper()
# uppercase()
# upperCase()
# toUpperCase()
# Enter your answer (a/b/c/d): a
# ...
